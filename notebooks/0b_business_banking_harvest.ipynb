# %%
from bs4 import BeautifulSoup
import os
import requests

# %%
def save_html(url: str, filename: str) -> None:
    """
    Saves the HTML content of a URL to a file under ../data directory.

    Args:
    url (str): The URL of the webpage to save.
    filename (str): The name of the file to save the HTML content to.

    Returns:
    None
    """
    # Create the data directory if it doesn't exist
    if not os.path.exists('../data'):
        os.makedirs('../data')

    # Get the HTML content of the URL
    response = requests.get(url)
    html_content = response.content

    # Save the HTML content to a file
    with open(f'../data/{filename}', 'wb') as f:
        f.write(html_content)

# %%
def get_links(filename: str) -> list:
    """
    Returns a list of all links in <a> tags in an HTML file.

    Args:
    filename (str): The name of the HTML file to parse.

    Returns:
    list: A list of all links in <a> tags in the HTML file.
    """
    # Open the HTML file and create a BeautifulSoup object
    with open(filename, 'r', encoding="latin-1") as f:
        html_doc = f.read()
    soup = BeautifulSoup(html_doc, 'html.parser')

    # Find all <a> tags and extract the href attribute
    links = []
    for a_tag in soup.find_all('a'):
        link = a_tag.get('href')
        if link:
            links.append(link)

    return links

# %%
class PageNode:
    def __init__(self, name:str, page_from:set() = set(), page_to:set() = set()) -> None:
        self._name = name
        self._page_from = page_from
        self._page_to = page_to

    @property
    def name(self) -> str:
        return self._name
    
    def __str__(self) -> str:
        return self.__repr__()
    
    def __repr__(self) -> str:
        return self._name
    
    def add_pages_to(self, pages:set()) -> None:
        self._page_to.update(pages)

# %%
prefix = "http://www.cibc.com"
initial_url = "/en/business.html"
filter_str = "/en/business"
#all_links = {"_personal-banking.html": {"name": "/personal-banking.html", "scraped": False, "page_from": set(), "page_to": set()}}
graph = {initial_url : PageNode(initial_url)}
to_visit = set({initial_url})
visited = set()

# %%
while len(to_visit) > 0:
    current = to_visit.pop()
    print("Visiting:", current)
    save_html(prefix + current, current.replace('/', '_'))

    visited.add(current)

    page_links = get_links(f'../data/{current.replace("/", "_")}')
    page_links = {link for link in page_links if link not in visited and link not in to_visit}
    page_links = {link for link in page_links if link.startswith(filter_str) and link.endswith('.html')}
    graph[current].add_pages_to(page_links)

    for i in graph[current]._page_to:
        if i not in visited:
            if i not in to_visit:
                graph[i] = PageNode(i)
                to_visit.add(i)
    
    print("Number of pages to visit:", len(to_visit), "\nNumber of Pages Visited:", len(visited))
# Out:
# Visiting: /en/business.html
# Number of pages to visit: 70
# Number of Pages Visited: 1
# Visiting: /en/business/advice-centre/articles/how-to.html
# Number of pages to visit: 69
# Number of Pages Visited: 2
# Visiting: /en/business/accounts/agriinvest-account.html
# Number of pages to visit: 74
# Number of Pages Visited: 3
# Visiting: /en/business/agriculture/protection/farm-credit-life-insurance.html
# Number of pages to visit: 75
# Number of Pages Visited: 4
# Visiting: /en/business/cash-management/smartbanking.html
# Number of pages to visit: 76
# Number of Pages Visited: 5
# Visiting: /en/business/credit-cards/aeroplan-visa-business.html
# Number of pages to visit: 76
# Number of Pages Visited: 6
# Visiting: /en/business/credit-cards/corporate-classic-plus-visa.html
# Number of pages to visit: 75
# Number of Pages Visited: 7
# Visiting: /en/business/accounts.html
# Number of pages to visit: 78
# Number of Pages Visited: 8
# Visiting: /en/business/accounts/agriinvest-account/fees-and-details.html
# Number of pages to visit: 78
# Number of Pages Visited: 9
# Visiting: /en/business/accounts/group-banking.html
# Number of pages to visit: 77
# Number of Pages Visited: 10
# Visiting: /en/business/join.html
# Number of pages to visit: 76
# Number of Pages Visited: 11
# Visiting: /en/business/accounts/unlimited-business-operating-account.html
# Number of pages to visit: 76
# Number of Pages Visited: 12
# Visiting: /en/business/covid-19/emergency-business-account-faq.html
# Number of pages to visit: 76
# Number of Pages Visited: 13
# Visiting: /en/business/accounts/basic-business-operating-account.html
# Number of pages to visit: 76
# Number of Pages Visited: 14
# Visiting: /en/business/banking-for-black-owned-businesses.html
# Number of pages to visit: 80
# Number of Pages Visited: 15
# Visiting: /en/business/advice-centre/starting-your-business.html
# Number of pages to visit: 79
# Number of Pages Visited: 16
# Visiting: /en/business/accounts/basic-business-operating-account/fees-and-details.html
# Number of pages to visit: 78
# Number of Pages Visited: 17
# Visiting: /en/business/cash-management/smartbanking/quickbooks.html
# Number of pages to visit: 77
# Number of Pages Visited: 18
# Visiting: /en/business/advice-centre/articles/how-to/creating-constructive-cash-reserves.html
# Number of pages to visit: 76
# Number of Pages Visited: 19
# Visiting: /en/business/cash-management.html
# Number of pages to visit: 91
# Number of Pages Visited: 20
# Visiting: /en/business/advice-centre/covid-19/cra-direct-deposit.html
# Number of pages to visit: 90
# Number of Pages Visited: 21
# Visiting: /en/business/accounts/advanced-business-operating-account.html
# Number of pages to visit: 91
# Number of Pages Visited: 22
# Visiting: /en/business/agriculture/loans-and-lines-of-credit.html
# Number of pages to visit: 100
# Number of Pages Visited: 23
# Visiting: /en/business/banking-for-professionals/healthcare/physicians.html
# Number of pages to visit: 99
# Number of Pages Visited: 24
# Visiting: /en/business/contact-us.html
# Number of pages to visit: 98
# Number of Pages Visited: 25
# Visiting: /en/business/banking-for-professionals/internationally-trained-dentists.html
# Number of pages to visit: 97
# Number of Pages Visited: 26
# Visiting: /en/business/accounts/terms-and-fees/accounts-no-longer-offered.html
# Number of pages to visit: 100
# Number of Pages Visited: 27
# Visiting: /en/business/advice-centre/managing-your-business.html
# Number of pages to visit: 101
# Number of Pages Visited: 28
# Visiting: /en/business/ways-to-bank.html
# Number of pages to visit: 101
# Number of Pages Visited: 29
# Visiting: /en/business/advice-centre/articles/client-stories/bernese-barista-story.html
# Number of pages to visit: 100
# Number of Pages Visited: 30
# Visiting: /en/business/agriculture/agriculture-services.html
# Number of pages to visit: 100
# Number of Pages Visited: 31
# Visiting: /en/business/banking-with-cibc/mobile-banking.html
# Number of pages to visit: 99
# Number of Pages Visited: 32
# Visiting: /en/business/cash-management/lockbox.html
